# %%
import pandas as pd
import numpy as np

br = "\n"

csv = pd.read_csv('housing.csv')
print('head of csv ',br,csv.head(2),br)
print('tail of csv ',br,csv.tail(2),br)
print('info of csv ',br,csv.info(),br)

tsv = pd.read_table('housing.csv')
print('head of tsv ',br,tsv.head(2),br)
print('tail of tsv ',br,tsv.tail(2),br)
print('info of tsv ',br,tsv.info(),br)

json = pd.read_json('housejson.json')
print('head of json',br,json.head(2),br)
print('tail of json',br,json.tail(2),br)
print('info of json',br,json.info(),br)
# Out:
# head of csv
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
#
# tail of csv
#         longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20638          INLAND
# ...

# %%
csv.groupby(['housing_median_age']).mean()
# Out:
#                      longitude   latitude  total_rooms  total_bedrooms  \
# housing_median_age
# 1.0                -119.457500  36.205000  1101.250000      172.000000
# 2.0                -119.121379  35.494483  5530.293103      913.758621
# 3.0                -118.936452  35.284516  7160.080645     1233.419355
# 4.0                -118.814293  34.966963  6237.282723     1113.042105
# 5.0                -118.918033  35.234262  5018.307377      935.814050
# 6.0                -118.994313  35.233125  4541.406250      864.006369
# 7.0                -119.111486  35.544286  5430.720000      994.398844
# 8.0                -119.320243  35.743835  3989.577670      764.192118
# 9.0                -119.305415  35.683366  3831.624390      722.578431
# 10.0               -119.400492  35.914621  3515.060606      685.851711
# 11.0               -119.484803  35.896063  3876.736220      757.496032
# 12.0               -119.346261  35.731891  4162.474790      827.288136
# ...

# %%
rename = csv.rename(columns={'latitude' : 'latti'})
print(rename.head(2))
rename = csv.rename(columns={'latti' : 'latitude'})
print(br,br,rename.head(2),br)
# Out:
#    longitude  latti  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23  37.88                41.0        880.0           129.0
# 1    -122.22  37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
#
#
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
