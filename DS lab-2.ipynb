# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('21B15600.csv')
df1=pd.read_csv('21B15600.csv')
df2=pd.read_csv('74B05600.csv')

# %%
df
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  mathscore  reading score  writing score
# 0                     NaN         72             72             74
# 1               completed         69             90             88
# 2                     NaN         90             95             93
# ...

# %%
#1.	Gather Columns into rows
pd.melt(df)
# Out:
#                        variable               value
# 0                        gender              female
# 1                        gender              female
# 2                        gender              female
# 3                        gender                male
# 4                        gender                male
# 5                        gender              female
# 6                        gender              female
# 7                        gender                male
# 8                        gender                male
# 9                race/ethnicity             group B
# 10               race/ethnicity             group C
# 11               race/ethnicity             group B
# 12               race/ethnicity             group A
# 13               race/ethnicity             group C
# 14               race/ethnicity             group B
# 15               race/ethnicity             group B
# 16               race/ethnicity             group B
# ...

# %%
#2.	Spread rows into columns
df.pivot(columns='mathscore')
# Out:
#           gender                                                            \
# mathscore     40    47    64      69      71      72    76      88      90
# 0            NaN   NaN   NaN     NaN     NaN  female   NaN     NaN     NaN
# 1            NaN   NaN   NaN  female     NaN     NaN   NaN     NaN     NaN
# 2            NaN   NaN   NaN     NaN     NaN     NaN   NaN     NaN  female
# 3            NaN  male   NaN     NaN     NaN     NaN   NaN     NaN     NaN
# 4            NaN   NaN   NaN     NaN     NaN     NaN  male     NaN     NaN
# 5            NaN   NaN   NaN     NaN  female     NaN   NaN     NaN     NaN
# 6            NaN   NaN   NaN     NaN     NaN     NaN   NaN  female     NaN
# 7           male   NaN   NaN     NaN     NaN     NaN   NaN     NaN     NaN
# 8            NaN   NaN  male     NaN     NaN     NaN   NaN     NaN     NaN
#
#           race/ethnicity  ... reading score writing score                    \
# ...

# %%
#3.	Append rows of Data Frames
pd.concat([df1,df2])
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#      gender         lunch  math score  mathscore parental level of education  \
# 0    female      standard         NaN       72.0           bachelor's degree
# 1    female      standard         NaN       69.0                some college
# 2    female      standard         NaN       90.0             master's degree
# 3      male  free/reduced         NaN       47.0          associate's degree
# 4      male      standard         NaN       76.0                some college
# 5    female      standard         NaN       71.0          associate's degree
# 6    female      standard         NaN       88.0                some college
# ...

# %%
#4.	Append columns of Data Frames
pd.concat([df1,df2], axis=1)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9       NaN            NaN                         NaN           NaN
# 10      NaN            NaN                         NaN           NaN
# 11      NaN            NaN                         NaN           NaN
# 12      NaN            NaN                         NaN           NaN
# ...

# %%
#5.	Order rows by values of a column
df.sort_values('mathscore')
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 7    male        group B                some college  free/reduced
# 3    male        group A          associate's degree  free/reduced
# 8    male        group D                 high school  free/reduced
# 1  female        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 0  female        group B           bachelor's degree      standard
# 4    male        group C                some college      standard
# 6  female        group B                some college      standard
# 2  female        group B             master's degree      standard
#
#   test preparation course  mathscore  reading score  writing score
# 7                     NaN         40             43             39
# 3                     NaN         47             57             44
# 8               completed         64             64             67
# ...

# %%
#6.	Order rows by values of a column 
df.sort_values('mathscore',ascending=False)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 2  female        group B             master's degree      standard
# 6  female        group B                some college      standard
# 4    male        group C                some college      standard
# 0  female        group B           bachelor's degree      standard
# 5  female        group B          associate's degree      standard
# 1  female        group C                some college      standard
# 8    male        group D                 high school  free/reduced
# 3    male        group A          associate's degree  free/reduced
# 7    male        group B                some college  free/reduced
#
#   test preparation course  mathscore  reading score  writing score
# 2                     NaN         90             95             93
# 6               completed         88             95             92
# 4                     NaN         76             78             75
# ...

# %%
#7.	Sort the index of a Data Frame
df.sort_index()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  mathscore  reading score  writing score
# 0                     NaN         72             72             74
# 1               completed         69             90             88
# 2                     NaN         90             95             93
# ...

# %%
#8.	Reset index of Data Frame to row numbers, moving index to columns.
df.reset_index()
# Out:
#    index  gender race/ethnicity parental level of education         lunch  \
# 0      0  female        group B           bachelor's degree      standard
# 1      1  female        group C                some college      standard
# 2      2  female        group B             master's degree      standard
# 3      3    male        group A          associate's degree  free/reduced
# 4      4    male        group C                some college      standard
# 5      5  female        group B          associate's degree      standard
# 6      6  female        group B                some college      standard
# 7      7    male        group B                some college  free/reduced
# 8      8    male        group D                 high school  free/reduced
#
#   test preparation course  mathscore  reading score  writing score
# 0                     NaN         72             72             74
# 1               completed         69             90             88
# ...

# %%
#9.	Drop columns from Data Frame
df.drop(columns=['gender','lunch'])
# Out:
#   race/ethnicity parental level of education test preparation course  \
# 0        group B           bachelor's degree                     NaN
# 1        group C                some college               completed
# 2        group B             master's degree                     NaN
# 3        group A          associate's degree                     NaN
# 4        group C                some college                     NaN
# 5        group B          associate's degree                     NaN
# 6        group B                some college               completed
# 7        group B                some college                     NaN
# 8        group D                 high school               completed
#
#    mathscore  reading score  writing score
# 0         72             72             74
# 1         69             90             88
# 2         90             95             93
# 3         47             57             44
# 4         76             78             75
# ...

# %%
#10.	Extract rows that meet logical criteria
df[df.mathscore > 50]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  mathscore  reading score  writing score
# 0                     NaN         72             72             74
# 1               completed         69             90             88
# 2                     NaN         90             95             93
# 4                     NaN         76             78             75
# 5                     NaN         71             83             78
# ...

# %%
#11.	Remove duplicate rows (only considers columns)
df.drop_duplicates()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  mathscore  reading score  writing score
# 0                     NaN         72             72             74
# 1               completed         69             90             88
# 2                     NaN         90             95             93
# ...

# %%
#12.	Select first n rows, Select last n rows
df.head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  mathscore  reading score  writing score
# 0                     NaN         72             72             74
# 1               completed         69             90             88

# %%
#13.	Select single column with specific name.
df['reading score']
# Out:
# 0    72
# 1    90
# 2    95
# 3    57
# 4    78
# 5    83
# 6    95
# 7    43
# 8    64
# Name: reading score, dtype: int64

# %%
#14.	Select Multiple column with specific name.
df[['reading score','writing score']]
# Out:
#    reading score  writing score
# 0             72             74
# 1             90             88
# 2             95             93
# 3             57             44
# 4             78             75
# 5             83             78
# 6             95             92
# 7             43             39
# 8             64             67

# %%
#II. Handling Missing Data
#15.	Drop rows with any column having NA/null data
df.dropna()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 1  female        group C                some college      standard
# 6  female        group B                some college      standard
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  mathscore  reading score  writing score
# 1               completed         69             90             88
# 6               completed         88             95             92
# 8               completed         64             64             67

# %%
#16.	Replace all NA/null data with value.
df.fillna(1)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  mathscore  reading score  writing score
# 0                       1         72             72             74
# 1               completed         69             90             88
# 2                       1         90             95             93
# ...

# %%
#III. Summarize data
len(df)
# Out:
# 9

# %%
#IV. Group Data
#Make new Columns
df = pd.DataFrame(df)
df.insert(1, "Age", [18, 19, 20, 21, 17, 16, 18, 19, 18], True) 
df
# Out:
#    gender  Age race/ethnicity parental level of education         lunch  \
# 0  female   18        group B           bachelor's degree      standard
# 1  female   19        group C                some college      standard
# 2  female   20        group B             master's degree      standard
# 3    male   21        group A          associate's degree  free/reduced
# 4    male   17        group C                some college      standard
# 5  female   16        group B          associate's degree      standard
# 6  female   18        group B                some college      standard
# 7    male   19        group B                some college  free/reduced
# 8    male   18        group D                 high school  free/reduced
#
#   test preparation course  mathscore  reading score  writing score
# 0                     NaN         72             72             74
# 1               completed         69             90             88
# ...

# %%
#V. Combine Data Sets
pd.merge(df1 , df2)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C                some college      standard
# 1  female        group B                some college      standard
# 2    male        group D                 high school  free/reduced
#
#   test preparation course  mathscore  reading score  writing score  math score
# 0               completed         69             90             88          69
# 1               completed         88             95             92          88
# 2               completed         64             64             67          64
